# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/macbook/Desktop/internship/data/Diabetes-Classification.csv")
df.head()
# Out:
#    Age  Gender   BMI Blood Pressure  FBS  HbA1c Family History of Diabetes  \
# 0   45    Male  25.0         Normal  100    5.7                         No
# 1   55  Female  30.0           High  120    6.4                        Yes
# 2   65    Male  35.0           High  140    7.1                        Yes
# 3   75  Female  40.0           High  160    7.8                        Yes
# 4   40    Male  20.0         Normal   80    5.0                         No
#
#   Smoking     Diet Exercise Diagnosis
# 0      No  Healthy  Regular        No
# 1     Yes     Poor       No       Yes
# 2     Yes     Poor       No       Yes
# 3     Yes     Poor       No       Yes
# 4      No  Healthy      NaN        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         128 non-null    int64
#  1   Gender                      128 non-null    object
#  2   BMI                         125 non-null    float64
#  3   Blood Pressure              128 non-null    object
#  4   FBS                         128 non-null    int64
#  5   HbA1c                       128 non-null    float64
#  6   Family History of Diabetes  126 non-null    object
#  7   Smoking                     126 non-null    object
#  8   Diet                        126 non-null    object
#  9   Exercise                    127 non-null    object
#  10  Diagnosis                   128 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# BMI                           3
# Blood Pressure                0
# FBS                           0
# HbA1c                         0
# Family History of Diabetes    2
# Smoking                       2
# Diet                          2
# Exercise                      1
# Diagnosis                     0
# dtype: int64

# %%
df=df.dropna()

# %%
df.head()
# Out:
#    Age  Gender   BMI Blood Pressure  FBS  HbA1c Family History of Diabetes  \
# 0   45    Male  25.0         Normal  100    5.7                         No
# 1   55  Female  30.0           High  120    6.4                        Yes
# 2   65    Male  35.0           High  140    7.1                        Yes
# 3   75  Female  40.0           High  160    7.8                        Yes
# 5   50  Female  25.0         Normal  100    5.7                         No
#
#   Smoking     Diet Exercise Diagnosis
# 0      No  Healthy  Regular        No
# 1     Yes     Poor       No       Yes
# 2     Yes     Poor       No       Yes
# 3     Yes     Poor       No       Yes
# 5      No  Healthy  Regular        No

# %%
#Problems with categorical values in columns:
#1: these are in string format
#2: categorical variables confuses

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
cat_col=['Diagnosis']

le=LabelEncoder()

for col in cat_col:
    df[col]=le.fit_transform(df[col])  
    
df.head()
# Out:
#    Age  Gender   BMI Blood Pressure  FBS  HbA1c Family History of Diabetes  \
# 0   45    Male  25.0         Normal  100    5.7                         No
# 1   55  Female  30.0           High  120    6.4                        Yes
# 2   65    Male  35.0           High  140    7.1                        Yes
# 3   75  Female  40.0           High  160    7.8                        Yes
# 5   50  Female  25.0         Normal  100    5.7                         No
#
#   Smoking     Diet Exercise  Diagnosis
# 0      No  Healthy  Regular          0
# 1     Yes     Poor       No          1
# 2     Yes     Poor       No          1
# 3     Yes     Poor       No          1
# 5      No  Healthy  Regular          0

# %%
#one hot encoding
one_encoded= pd.get_dummies(df,columns=['Gender'])
one_encoded.head()
# Out:
#    Age   BMI Blood Pressure  FBS  HbA1c Family History of Diabetes Smoking  \
# 0   45  25.0         Normal  100    5.7                         No      No
# 1   55  30.0           High  120    6.4                        Yes     Yes
# 2   65  35.0           High  140    7.1                        Yes     Yes
# 3   75  40.0           High  160    7.8                        Yes     Yes
# 5   50  25.0         Normal  100    5.7                         No      No
#
#       Diet Exercise  Diagnosis  Gender_Female  Gender_Male
# 0  Healthy  Regular          0          False         True
# 1     Poor       No          1           True        False
# 2     Poor       No          1          False         True
# 3     Poor       No          1           True        False
# 5  Healthy  Regular          0           True        False

# %%
#how to choose either label encoding or onehot encoding:
#it depends on the type of categorical variable:

#label encoding: when values in features are ordinal: order Ex: Education - Bachelors>Masters>Doctorate
#Onehotending: When categories are not in order (Nominal Values):  Gender- Male, Female, Smoking etc

# %%
#we are applying one hot encoding

cat_col=['Gender','Exercise','Blood Pressure', 'Family History of Diabetes', 'Smoking', 'Diet']

one_encoded= pd.get_dummies(df,columns=cat_col)

# %%
one_encoded.head()
# Out:
#    Age   BMI  FBS  HbA1c  Diagnosis  Gender_Female  Gender_Male  Exercise_No  \
# 0   45  25.0  100    5.7          0          False         True        False
# 1   55  30.0  120    6.4          1           True        False         True
# 2   65  35.0  140    7.1          1          False         True         True
# 3   75  40.0  160    7.8          1           True        False         True
# 5   50  25.0  100    5.7          0           True        False        False
#
#    Exercise_Regular  Blood Pressure_High  Blood Pressure_Low  \
# 0              True                False               False
# 1             False                 True               False
# 2             False                 True               False
# 3             False                 True               False
# 5              True                False               False
#
#    Blood Pressure_Normal  Family History of Diabetes_No  \
# 0                   True                           True
# 1                  False                          False
# 2                  False                          False
# 3                  False                          False
# 5                   True                           True
#
#    Family History of Diabetes_Yes  Smoking_No  Smoking_Yes  Diet_Healthy  \
# 0                           False        True        False          True
# 1                            True       False         True         False
# 2                            True       False         True         False
# 3                            True       False         True         False
# 5                           False        True        False          True
#
#    Diet_Poor
# 0      False
# 1       True
# 2       True
# 3       True
# 5      False

# %%
#label encoding the one hot encoded columns to convert all the string values in newly generated columns to integers
cat_col=[ 'Gender_Female',
       'Gender_Male', 'Exercise_No', 'Exercise_Regular', 'Blood Pressure_High',
       'Blood Pressure_Low', 'Blood Pressure_Normal',
       'Family History of Diabetes_No', 'Family History of Diabetes_Yes',
       'Smoking_No', 'Smoking_Yes', 'Diet_Healthy', 'Diet_Poor']
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in cat_col:
    one_encoded[col]=le.fit_transform(one_encoded[col])

# %%
one_encoded.head()
# Out:
#    Age   BMI  FBS  HbA1c  Diagnosis  Gender_Female  Gender_Male  Exercise_No  \
# 0   45  25.0  100    5.7          0              0            1            0
# 1   55  30.0  120    6.4          1              1            0            1
# 2   65  35.0  140    7.1          1              0            1            1
# 3   75  40.0  160    7.8          1              1            0            1
# 5   50  25.0  100    5.7          0              1            0            0
#
#    Exercise_Regular  Blood Pressure_High  Blood Pressure_Low  \
# 0                 1                    0                   0
# 1                 0                    1                   0
# 2                 0                    1                   0
# 3                 0                    1                   0
# 5                 1                    0                   0
#
#    Blood Pressure_Normal  Family History of Diabetes_No  \
# 0                      1                              1
# 1                      0                              0
# 2                      0                              0
# 3                      0                              0
# 5                      1                              1
#
#    Family History of Diabetes_Yes  Smoking_No  Smoking_Yes  Diet_Healthy  \
# 0                               0           1            0             1
# 1                               1           0            1             0
# 2                               1           0            1             0
# 3                               1           0            1             0
# 5                               0           1            0             1
#
#    Diet_Poor
# 0          0
# 1          1
# 2          1
# 3          1
# 5          0

# %%
df.describe()
# Out:
#              Age         BMI         FBS       HbA1c   Diagnosis
# count  118.00000  118.000000  118.000000  118.000000  118.000000
# mean    43.09322   36.220339  163.559322    7.924576    0.254237
# std     21.46792   16.542685   62.244698    2.178564    0.437288
# min     12.00000   10.000000   80.000000    5.000000    0.000000
# 25%     28.00000   24.000000  120.000000    6.400000    0.000000
# 50%     40.00000   34.000000  160.000000    7.800000    0.000000
# 75%     56.50000   48.500000  220.000000    9.900000    0.750000
# max    185.00000  105.000000  280.000000   12.000000    1.000000

# %%
df['BMI'].value_counts()
# Out:
# BMI
# 25.0     7
# 19.0     6
# 34.0     6
# 30.0     5
# 35.0     5
# 40.0     5
# 29.0     5
# 39.0     5
# 15.0     5
# 24.0     5
# 44.0     4
# 59.0     4
# 54.0     4
# 20.0     4
# 32.0     3
# 27.0     3
# 22.0     3
# 17.0     3
# 10.0     3
# 49.0     3
# 14.0     3
# 37.0     3
# 42.0     3
# 55.0     2
# 50.0     2
# 65.0     2
# 52.0     2
# 47.0     2
# 60.0     2
# 67.0     2
# 62.0     2
# 57.0     2
# 64.0     2
# 105.0    1
# Name: count, dtype: int64

# %%
one_encoded.corr()
# Out:
#                                      Age       BMI       FBS     HbA1c  \
# Age                             1.000000  0.507919  0.527564  0.527564
# BMI                             0.507919  1.000000  0.857341  0.857341
# FBS                             0.527564  0.857341  1.000000  1.000000
# HbA1c                           0.527564  0.857341  1.000000  1.000000
# Diagnosis                      -0.180084 -0.318549 -0.334980 -0.334980
# Gender_Female                   0.006891  0.097230  0.048463  0.048463
# Gender_Male                    -0.006891 -0.097230 -0.048463 -0.048463
# Exercise_No                    -0.035988 -0.101395 -0.159299 -0.159299
# Exercise_Regular                0.035988  0.101395  0.159299  0.159299
# Blood Pressure_High             0.344591  0.628011  0.776987  0.776987
# Blood Pressure_Low             -0.293137 -0.379066 -0.410231 -0.410231
# Blood Pressure_Normal          -0.187701 -0.436695 -0.576113 -0.576113
# Family History of Diabetes_No  -0.177848 -0.179331 -0.120855 -0.120855
# Family History of Diabetes_Yes  0.177848  0.179331  0.120855  0.120855
# Smoking_No                      0.035988  0.101395  0.159299  0.159299
# Smoking_Yes                    -0.035988 -0.101395 -0.159299 -0.159299
# Diet_Healthy                    0.035988  0.101395  0.159299  0.159299
# Diet_Poor                      -0.035988 -0.101395 -0.159299 -0.159299
#
#                                 Diagnosis  Gender_Female  Gender_Male  \
# Age                             -0.180084       0.006891    -0.006891
# BMI                             -0.318549       0.097230    -0.097230
# FBS                             -0.334980       0.048463    -0.048463
# HbA1c                           -0.334980       0.048463    -0.048463
# Diagnosis                        1.000000       0.019804    -0.019804
# Gender_Female                    0.019804       1.000000    -1.000000
# Gender_Male                     -0.019804      -1.000000     1.000000
# Exercise_No                      0.450225       0.008916    -0.008916
# Exercise_Regular                -0.450225      -0.008916     0.008916
# Blood Pressure_High             -0.182689       0.165402    -0.165402
# Blood Pressure_Low               0.171745      -0.294144     0.294144
# Blood Pressure_Normal            0.089552       0.003461    -0.003461
# Family History of Diabetes_No    0.355782      -0.010275     0.010275
# Family History of Diabetes_Yes  -0.355782       0.010275    -0.010275
# Smoking_No                      -0.450225      -0.008916     0.008916
# Smoking_Yes                      0.450225       0.008916    -0.008916
# Diet_Healthy                    -0.450225      -0.008916     0.008916
# Diet_Poor                        0.450225       0.008916    -0.008916
#
#                                 Exercise_No  Exercise_Regular  \
# Age                               -0.035988          0.035988
# BMI                               -0.101395          0.101395
# FBS                               -0.159299          0.159299
# HbA1c                             -0.159299          0.159299
# Diagnosis                          0.450225         -0.450225
# Gender_Female                      0.008916         -0.008916
# Gender_Male                       -0.008916          0.008916
# Exercise_No                        1.000000         -1.000000
# Exercise_Regular                  -1.000000          1.000000
# Blood Pressure_High               -0.064211          0.064211
# Blood Pressure_Low                -0.017065          0.017065
# Blood Pressure_Normal              0.078686         -0.078686
# Family History of Diabetes_No     -0.627379          0.627379
# Family History of Diabetes_Yes     0.627379         -0.627379
# Smoking_No                        -1.000000          1.000000
# Smoking_Yes                        1.000000         -1.000000
# Diet_Healthy                      -1.000000          1.000000
# Diet_Poor                          1.000000         -1.000000
#
#                                 Blood Pressure_High  Blood Pressure_Low  \
# Age                                        0.344591           -0.293137
# BMI                                        0.628011           -0.379066
# FBS                                        0.776987           -0.410231
# HbA1c                                      0.776987           -0.410231
# Diagnosis                                 -0.182689            0.171745
# Gender_Female                              0.165402           -0.294144
# Gender_Male                               -0.165402            0.294144
# Exercise_No                               -0.064211           -0.017065
# Exercise_Regular                           0.064211            0.017065
# Blood Pressure_High                        1.000000           -0.387564
# Blood Pressure_Low                        -0.387564            1.000000
# Blood Pressure_Normal                     -0.827085           -0.197598
# Family History of Diabetes_No             -0.139841            0.185418
# Family History of Diabetes_Yes             0.139841           -0.185418
# Smoking_No                                 0.064211            0.017065
# Smoking_Yes                               -0.064211           -0.017065
# Diet_Healthy                               0.064211            0.017065
# Diet_Poor                                 -0.064211           -0.017065
#
#                                 Blood Pressure_Normal  \
# Age                                         -0.187701
# BMI                                         -0.436695
# FBS                                         -0.576113
# HbA1c                                       -0.576113
# Diagnosis                                    0.089552
# Gender_Female                                0.003461
# Gender_Male                                 -0.003461
# Exercise_No                                  0.078686
# Exercise_Regular                            -0.078686
# Blood Pressure_High                         -0.827085
# Blood Pressure_Low                          -0.197598
# Blood Pressure_Normal                        1.000000
# Family History of Diabetes_No                0.035651
# Family History of Diabetes_Yes              -0.035651
# Smoking_No                                  -0.078686
# Smoking_Yes                                  0.078686
# Diet_Healthy                                -0.078686
# Diet_Poor                                    0.078686
#
#                                 Family History of Diabetes_No  \
# Age                                                 -0.177848
# BMI                                                 -0.179331
# FBS                                                 -0.120855
# HbA1c                                               -0.120855
# Diagnosis                                            0.355782
# Gender_Female                                       -0.010275
# Gender_Male                                          0.010275
# Exercise_No                                         -0.627379
# Exercise_Regular                                     0.627379
# Blood Pressure_High                                 -0.139841
# Blood Pressure_Low                                   0.185418
# Blood Pressure_Normal                                0.035651
# Family History of Diabetes_No                        1.000000
# Family History of Diabetes_Yes                      -1.000000
# Smoking_No                                           0.627379
# Smoking_Yes                                         -0.627379
# Diet_Healthy                                         0.627379
# Diet_Poor                                           -0.627379
#
#                                 Family History of Diabetes_Yes  Smoking_No  \
# Age                                                   0.177848    0.035988
# BMI                                                   0.179331    0.101395
# FBS                                                   0.120855    0.159299
# HbA1c                                                 0.120855    0.159299
# Diagnosis                                            -0.355782   -0.450225
# Gender_Female                                         0.010275   -0.008916
# Gender_Male                                          -0.010275    0.008916
# Exercise_No                                           0.627379   -1.000000
# Exercise_Regular                                     -0.627379    1.000000
# Blood Pressure_High                                   0.139841    0.064211
# Blood Pressure_Low                                   -0.185418    0.017065
# Blood Pressure_Normal                                -0.035651   -0.078686
# Family History of Diabetes_No                        -1.000000    0.627379
# Family History of Diabetes_Yes                        1.000000   -0.627379
# Smoking_No                                           -0.627379    1.000000
# Smoking_Yes                                           0.627379   -1.000000
# Diet_Healthy                                         -0.627379    1.000000
# Diet_Poor                                             0.627379   -1.000000
#
#                                 Smoking_Yes  Diet_Healthy  Diet_Poor
# Age                               -0.035988      0.035988  -0.035988
# BMI                               -0.101395      0.101395  -0.101395
# FBS                               -0.159299      0.159299  -0.159299
# HbA1c                             -0.159299      0.159299  -0.159299
# Diagnosis                          0.450225     -0.450225   0.450225
# Gender_Female                      0.008916     -0.008916   0.008916
# Gender_Male                       -0.008916      0.008916  -0.008916
# Exercise_No                        1.000000     -1.000000   1.000000
# Exercise_Regular                  -1.000000      1.000000  -1.000000
# Blood Pressure_High               -0.064211      0.064211  -0.064211
# Blood Pressure_Low                -0.017065      0.017065  -0.017065
# Blood Pressure_Normal              0.078686     -0.078686   0.078686
# Family History of Diabetes_No     -0.627379      0.627379  -0.627379
# Family History of Diabetes_Yes     0.627379     -0.627379   0.627379
# Smoking_No                        -1.000000      1.000000  -1.000000
# Smoking_Yes                        1.000000     -1.000000   1.000000
# Diet_Healthy                      -1.000000      1.000000  -1.000000
# Diet_Poor                          1.000000     -1.000000   1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['BMI'], bins=10, kde=True)
sns.histplot(df['FBS'], bins=20, kde=False)
plt.show()

# %%
# Age by Gender
sns.boxplot(x='Gender', y='Age', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
	
#Feature Selection: Removing irrelevant features which does not contribute towards the label(Diagnosis)
#defining feature selection model
from sklearn.feature_selection import SelectKBest, f_classif

selector = SelectKBest(score_func=f_classif, k=5)

# %%
#splitting label and features
x=one_encoded.drop('Diagnosis', axis=1)
y=one_encoded['Diagnosis']

# %%
#applying feature selection
x_selected=selector.fit_transform(x,y)
selected_features=x.columns[selector.get_support()]
print(selected_features)
# Out:
# Index(['Exercise_Regular', 'Smoking_No', 'Smoking_Yes', 'Diet_Healthy',
#        'Diet_Poor'],
#       dtype='object')

# %%
#created df with selected features
x1=one_encoded[selected_features]

# %%
#train test split
from sklearn.model_selection import train_test_split

#for all features
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.4,random_state=10)

# %%
#building knn models
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier(n_neighbors=5)
knn_selected=KNeighborsClassifier(n_neighbors=5)

# %%
#training models
#all features
knn.fit(x_train,y_train)
y_pred_knn=knn.predict(x_test)

#selcted features
knn_selected.fit(x_train,y_train)
y_pred_knn1=knn_selected.predict(x_test)

# %%
#classification report

from sklearn.metrics import classification_report

print("nKNN Performance:")
print(classification_report(y_test, y_pred_knn))

print("nKNN_Selected Performance:")
print(classification_report(y_test, y_pred_knn1))
# Out:
# nKNN Performance:
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75        39
#            1       0.20      0.33      0.25         9
#
#     accuracy                           0.62        48
#    macro avg       0.51      0.51      0.50        48
# weighted avg       0.70      0.62      0.66        48
#
# nKNN_Selected Performance:
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75        39
#            1       0.20      0.33      0.25         9
#
#     accuracy                           0.62        48
#    macro avg       0.51      0.51      0.50        48
# weighted avg       0.70      0.62      0.66        48

# %%
#building svm models
from sklearn.svm import SVC

svm=SVC(kernel='rbf', probability=True,random_state=10 )
svm_selected=SVC(kernel='rbf', probability=True,random_state=10 )

# %%
#building svm models
from sklearn.svm import SVC

svm=SVC(kernel='rbf', probability=True,random_state=10 )
svm_selected=SVC(kernel='rbf', probability=True,random_state=10 )

# %%
#training models
#all features
svm.fit(x_train,y_train)
y_pred_svm=svm.predict(x_test)


#selcted features
svm_selected.fit(x_train,y_train)
y_pred_svm1=svm_selected.predict(x_test)

# %%
#classification report

from sklearn.metrics import classification_report

print("SVM Performance:")
print(classification_report(y_test, y_pred_svm))

print("nSVM_Selected Performance:")
print(classification_report(y_test, y_pred_svm))
# Out:
# SVM Performance:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90        39
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.81        48
#    macro avg       0.41      0.50      0.45        48
# weighted avg       0.66      0.81      0.73        48
#
# nSVM_Selected Performance:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90        39
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.81        48
#    macro avg       0.41      0.50      0.45        48
# weighted avg       0.66      0.81      0.73        48
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
#confusion: it show labelwise performance of the model

from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred_svm)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
#plot ROC curve for svm all features model
from sklearn.metrics import roc_auc_score, roc_curve

y_proba = svm.predict_proba(x_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_proba)
plt.plot(fpr, tpr, label=f'{'svm'} (AUC = {roc_auc_score(y_test, y_proba):.2f})')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for SVM(all features) model')
plt.legend()
plt.show()
