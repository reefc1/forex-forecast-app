# %%
# !pip install pandas numpy matplotlib scikit-learn seaborn
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-macosx_10_9_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting numpy
#   Downloading numpy-2.2.6-cp310-cp310-macosx_14_0_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp310-cp310-macosx_10_12_x86_64.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-macosx_10_9_x86_64.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 3.5 MB/s eta 0:00:0000:0100:01
# Collecting python-dateutil>=2.8.2
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 2.8 MB/s eta 0:00:0000:0100:01
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp310-cp310-macosx_10_10_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.6/268.6 kB 2.9 MB/s eta 0:00:0000:0100:01
# Collecting packaging>=20.0
#   Downloading packaging-25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-macosx_10_9_x86_64.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Collecting pyparsing>=3
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 2.0 MB/s eta 0:00:0000:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp310-cp310-macosx_10_9_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 3.1 MB/s eta 0:00:0000:0100:01
# Collecting scipy>=1.8.0
#   Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_x86_64.whl (25.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting six>=1.5
#   Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, six, pyparsing, pillow, packaging, numpy, kiwisolver, joblib, fonttools, cycler, scipy, python-dateutil, contourpy, scikit-learn, pandas, matplotlib, seaborn
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.60.1 joblib-1.5.2 kiwisolver-1.4.9 matplotlib-3.10.7 numpy-2.2.6 packaging-25.0 pandas-2.3.3 pillow-11.3.0 pyparsing-3.2.5 python-dateutil-2.9.0.post0 pytz-2025.2 scikit-learn-1.7.2 scipy-1.15.3 seaborn-0.13.2 six-1.17.0 threadpoolctl-3.6.0 tzdata-2025.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# %matplotlib inline

# %%
#load data set
df = pd.read_csv("/Users/macbook/Desktop/internship/data/Diabetes.csv")

# %%
# Display dataset info
print("Dataset Shape:", df.shape)
print("\nFirst 5 Rows:")
df.head()
# Out:
# Dataset Shape: (128, 11)
#
# First 5 Rows:
#    Age  Gender   BMI Blood Pressure  FBS  HbA1c Family History of Diabetes  \
# 0   45    Male  25.0         Normal  100    5.7                         No
# 1   55  Female  30.0           High  120    6.4                        Yes
# 2   65    Male  35.0           High  140    7.1                        Yes
# 3   75  Female  40.0           High  160    7.8                        Yes
# 4   40    Male  20.0         Normal   80    5.0                         No
#
#   Smoking     Diet Exercise Diagnosis
# 0      No  Healthy  Regular        No
# 1     Yes     Poor       No       Yes
# 2     Yes     Poor       No       Yes
# 3     Yes     Poor       No       Yes
# 4      No  Healthy      NaN        No

# %%
# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Handle missing values by dropping rows
df = df.dropna()
# Out:
# Missing Values:
# Age                           0
# Gender                        0
# BMI                           3
# Blood Pressure                0
# FBS                           0
# HbA1c                         0
# Family History of Diabetes    2
# Smoking                       2
# Diet                          2
# Exercise                      1
# Diagnosis                     0
# dtype: int64

# %%
# Check column names
print("\nColumn Names:")
print(df.columns)

# Preprocessing
# Identify categorical and numerical columns
categorical_cols = ['Gender', 'Blood Pressure', 'Family History of Diabetes', 'Smoking', 'Diet', 'Exercise']
numerical_cols = ['Age', 'BMI', 'FBS', 'HbA1c']

# Target column
target_column = 'Diagnosis'
# Out:
# Column Names:
# Index(['Age', 'Gender', 'BMI', 'Blood Pressure', 'FBS', 'HbA1c',
#        'Family History of Diabetes', 'Smoking', 'Diet', 'Exercise',
#        'Diagnosis'],
#       dtype='object')

# %%
# Create a ColumnTransformer to preprocess the data in the columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

# %%
# Split features and target
X = df.drop(target_column, axis=1)
y = df[target_column]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Apply preprocessing
X_train_scaled = preprocessor.fit_transform(X_train)
X_test_scaled = preprocessor.transform(X_test)

# Convert y_train and y_test to binary (label encoding)
y_train = y_train.map({'No': 0, 'Yes': 1}).values
y_test = y_test.map({'No': 0, 'Yes': 1}).values

# Convert X_train_scaled and X_test_scaled to NumPy arrays (Tensorflow does not accept pandas dataframe as input, it accepts either Tensorflow tensors or NumPy arrays)
X_train_scaled = X_train_scaled.astype('float32')
X_test_scaled = X_test_scaled.astype('float32')

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8769 - loss: 0.2674 - val_accuracy: 0.7059 - val_loss: 0.4093
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9077 - loss: 0.2511 - val_accuracy: 0.7059 - val_loss: 0.4061
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9231 - loss: 0.2429 - val_accuracy: 0.7059 - val_loss: 0.4031
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9231 - loss: 0.2437 - val_accuracy: 0.7059 - val_loss: 0.4006
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8923 - loss: 0.2565 - val_accuracy: 0.7059 - val_loss: 0.3920
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9385 - loss: 0.2474 - val_accuracy: 0.8824 - val_loss: 0.3768
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9231 - loss: 0.2529 - val_accuracy: 0.8824 - val_loss: 0.3667
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9385 - loss: 0.2200 - val_accuracy: 0.8824 - val_loss: 0.3592
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9385 - loss: 0.2305 - val_accuracy: 0.8824 - val_loss: 0.3534
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9385 - loss: 0.2280 - val_accuracy: 0.8824 - val_loss: 0.3485
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9538 - loss: 0.2200 - val_accuracy: 0.8824 - val_loss: 0.3434
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9231 - loss: 0.2160 - val_accuracy: 0.8824 - val_loss: 0.3387
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9385 - loss: 0.2221 - val_accuracy: 0.8824 - val_loss: 0.3341
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9077 - loss: 0.2137 - val_accuracy: 0.8824 - val_loss: 0.3279
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9692 - loss: 0.1973 - val_accuracy: 0.8824 - val_loss: 0.3191
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9538 - loss: 0.2114 - val_accuracy: 0.8824 - val_loss: 0.3110

# %%
# Evaluate the model
y_pred_tf = (tf_model.predict(X_test_scaled) > 0.3).astype(int)
print("\nTensorFlow MLP Performance:")
print("Accuracy:", accuracy_score(y_test, y_pred_tf))
print("Classification Report:")
print(classification_report(y_test, y_pred_tf))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_tf))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
#
# TensorFlow MLP Performance:
# Accuracy: 0.9722222222222222
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        27
#            1       0.90      1.00      0.95         9
#
#     accuracy                           0.97        36
#    macro avg       0.95      0.98      0.96        36
# weighted avg       0.98      0.97      0.97        36
#
# Confusion Matrix:
# [[26  1]
#  [ 0  9]]

# %%
# Plot training history
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss (TensorFlow)')
plt.legend()
plt.show()

# %%
print(pd.Series(y_train).value_counts())
# Out:
# 0    61
# 1    21
# Name: count, dtype: int64

# %%
#handle imbalance
from sklearn.utils import class_weight

# Compute balanced class weights
class_weights = dict(enumerate(class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)))
print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: 0.6721311475409836, 1: 1.9523809523809523}

# %%
#baseline model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

#suppress warnings
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Baseline model
tf_model1 = Sequential([
    Input(shape=(X_train_scaled.shape[1],)),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

tf_model1.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history1 = tf_model1.fit(
    X_train_scaled, y_train, 
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.4000 - loss: 0.6832 - val_accuracy: 0.4706 - val_loss: 0.7000
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5538 - loss: 0.6605 - val_accuracy: 0.5294 - val_loss: 0.6746
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5846 - loss: 0.6518 - val_accuracy: 0.6471 - val_loss: 0.6522
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7231 - loss: 0.6206 - val_accuracy: 0.7059 - val_loss: 0.6335
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7692 - loss: 0.6012 - val_accuracy: 0.7059 - val_loss: 0.6179
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7846 - loss: 0.5839 - val_accuracy: 0.7059 - val_loss: 0.6056
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8154 - loss: 0.5691 - val_accuracy: 0.7059 - val_loss: 0.5950
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8308 - loss: 0.5800 - val_accuracy: 0.7059 - val_loss: 0.5865
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8308 - loss: 0.5516 - val_accuracy: 0.7059 - val_loss: 0.5812
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9846 - loss: 0.1347 - val_accuracy: 0.9412 - val_loss: 0.1783
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9385 - loss: 0.1463 - val_accuracy: 0.9412 - val_loss: 0.1655
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9692 - loss: 0.1295 - val_accuracy: 0.9412 - val_loss: 0.1566
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9692 - loss: 0.1192 - val_accuracy: 0.9412 - val_loss: 0.1489
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9538 - loss: 0.1224 - val_accuracy: 0.9412 - val_loss: 0.1410
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0886 - val_accuracy: 0.9412 - val_loss: 0.1333
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9692 - loss: 0.0931 - val_accuracy: 0.9412 - val_loss: 0.1262
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9846 - loss: 0.0917 - val_accuracy: 0.9412 - val_loss: 0.1197
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9846 - loss: 0.0855 - val_accuracy: 0.9412 - val_loss: 0.1148
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9846 - loss: 0.0917 - val_accuracy: 0.9412 - val_loss: 0.1105
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9846 - loss: 0.0613 - val_accuracy: 0.9412 - val_loss: 0.1028
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9846 - loss: 0.0729 - val_accuracy: 0.9412 - val_loss: 0.0949
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0695 - val_accuracy: 0.9412 - val_loss: 0.0923
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0566 - val_accuracy: 0.9412 - val_loss: 0.0918
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0526 - val_accuracy: 0.9412 - val_loss: 0.0881
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9692 - loss: 0.0834 - val_accuracy: 0.9412 - val_loss: 0.0806
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0367 - val_accuracy: 0.9412 - val_loss: 0.0727
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 1.0000 - val_loss: 0.0666
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9846 - loss: 0.0365 - val_accuracy: 1.0000 - val_loss: 0.0605
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0425 - val_accuracy: 1.0000 - val_loss: 0.0564
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9692 - loss: 0.0457 - val_accuracy: 1.0000 - val_loss: 0.0556
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9846 - loss: 0.0401 - val_accuracy: 1.0000 - val_loss: 0.0549
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0394 - val_accuracy: 1.0000 - val_loss: 0.0536

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

y_pred_prob = tf_model2.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred, labels=[0,1]))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        27
#            1       1.00      1.00      1.00         9
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# Confusion Matrix:
#  [[27  0]
#  [ 0  9]]

# %%
import numpy as np
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1]), array([27,  9]))

# %%
from tensorflow.keras.callbacks import EarlyStopping
tf_model3 = Sequential([
    Input(shape=(X_train_scaled.shape[1],)),
    Dense(128, activation='relu'),
    Dropout(0.3),   # reduced dropout
    Dense(64, activation='relu'),
    Dropout(0.2),   # reduced dropout
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

tf_model3.compile(
    optimizer=Adam(learning_rate=0.0005),  
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Add early stopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,              # stop if val_loss doesn’t improve for 10 epochs
    restore_best_weights=True
)    
# Train using class weights
history3 = tf_model3.fit(
    X_train_scaled, y_train, 
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop],
    class_weight=class_weights,   # <-- balanced training
    verbose=1
)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.2769 - loss: 0.7576 - val_accuracy: 0.3529 - val_loss: 0.7977
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2462 - loss: 0.7381 - val_accuracy: 0.3529 - val_loss: 0.7723
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2769 - loss: 0.7121 - val_accuracy: 0.3529 - val_loss: 0.7549
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2923 - loss: 0.6913 - val_accuracy: 0.4706 - val_loss: 0.7366
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3385 - loss: 0.6550 - val_accuracy: 0.5294 - val_loss: 0.7202
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5231 - loss: 0.6143 - val_accuracy: 0.7059 - val_loss: 0.7082
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6308 - loss: 0.6049 - val_accuracy: 0.7059 - val_loss: 0.6961
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5538 - loss: 0.6197 - val_accuracy: 0.7059 - val_loss: 0.6848
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6615 - loss: 0.5722 - val_accuracy: 0.7059 - val_loss: 0.6761
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6769 - loss: 0.5651 - val_accuracy: 0.6471 - val_loss: 0.6653
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7846 - loss: 0.5441 - val_accuracy: 0.6471 - val_loss: 0.6541
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7385 - loss: 0.5767 - val_accuracy: 0.6471 - val_loss: 0.6436
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7846 - loss: 0.5434 - val_accuracy: 0.7059 - val_loss: 0.6355
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7692 - loss: 0.5466 - val_accuracy: 0.6471 - val_loss: 0.6265
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9692 - loss: 0.2205 - val_accuracy: 0.8235 - val_loss: 0.3505
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9692 - loss: 0.2530 - val_accuracy: 0.8235 - val_loss: 0.3492
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9538 - loss: 0.2597 - val_accuracy: 0.8235 - val_loss: 0.3487
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9385 - loss: 0.2365 - val_accuracy: 0.8235 - val_loss: 0.3492
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9385 - loss: 0.2157 - val_accuracy: 0.8824 - val_loss: 0.3489
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9231 - loss: 0.2206 - val_accuracy: 0.8235 - val_loss: 0.3465
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9231 - loss: 0.2298 - val_accuracy: 0.8235 - val_loss: 0.3418
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9385 - loss: 0.1998 - val_accuracy: 0.7647 - val_loss: 0.3353
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8923 - loss: 0.2164 - val_accuracy: 0.7647 - val_loss: 0.3279
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9077 - loss: 0.2061 - val_accuracy: 0.8235 - val_loss: 0.3306
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9077 - loss: 0.2031 - val_accuracy: 0.8235 - val_loss: 0.3422
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8615 - loss: 0.1934 - val_accuracy: 0.7647 - val_loss: 0.3514
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9231 - loss: 0.1668 - val_accuracy: 0.7647 - val_loss: 0.3583
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8923 - loss: 0.1918 - val_accuracy: 0.7647 - val_loss: 0.3610
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8923 - loss: 0.1868 - val_accuracy: 0.7647 - val_loss: 0.3592

# %%
y_pred_prob = tf_model4.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred, labels=[0,1]))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Accuracy: 0.9444444444444444
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        27
#            1       0.82      1.00      0.90         9
#
#     accuracy                           0.94        36
#    macro avg       0.91      0.96      0.93        36
# weighted avg       0.95      0.94      0.95        36
#
# Confusion Matrix:
#  [[25  2]
#  [ 0  9]]

# %%
#ptimal balance between accuracy and generalisation. It avoided overfitting seen in Model 2 while improving class 1 recall 
#compared to Model 3. With 94 % overall accuracy and perfect recall for the minority class, Model 4 represents the best 
#fine-tuned configuration

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, precision_recall_curve, average_precision_score

# --- 1. Predictions ---
y_pred_prob = tf_model4.predict(X_test_scaled)       # probabilities
y_pred = (y_pred_prob > 0.5).astype(int).flatten()   # binary predictions

# --- 2. Classification Report ---
print("Classification Report:")
print(classification_report(y_test, y_pred))

# --- 3. Confusion Matrix ---
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0,1], yticklabels=[0,1])
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# --- 4. ROC Curve & AUC ---
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0,1], [0,1], color='gray', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# --- 5. Precision-Recall Curve & Average Precision ---
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred_prob)
avg_precision = average_precision_score(y_test, y_pred_prob)

plt.figure()
plt.plot(recall, precision, color='green', lw=2, label='PR curve (AP = %0.2f)' % avg_precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.show()

# --- 6. Training & Validation Loss/Accuracy Plots ---
plt.figure(figsize=(12,5))

# Accuracy plot
plt.subplot(1,2,1)
plt.plot(history4.history['accuracy'], label='Train Accuracy')
plt.plot(history4.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy')
plt.legend()

# Loss plot
plt.subplot(1,2,2)
plt.plot(history4.history['loss'], label='Train Loss')
plt.plot(history4.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.lege
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        27
#            1       0.82      1.00      0.90         9
#
#     accuracy                           0.94        36
#    macro avg       0.91      0.96      0.93        36
# weighted avg       0.95      0.94      0.95        36
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 64
#      62 plt.ylabel('Loss')
#      63 plt.title('Training & Validation Loss')
# ---> 64 plt.lege
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'lege'
