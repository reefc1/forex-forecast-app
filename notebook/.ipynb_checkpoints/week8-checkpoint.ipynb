# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from datetime import date

# %%
clim = pd.read_csv("/Users/macbook/Desktop/internship/data/climate.csv")

# %%
clim = clim.reset_index()
clim.head()
# Out:
#    index            Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0      0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1      1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2      2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3      3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4      4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
#
#    rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0    93.3          3.33          3.11          0.22       1.94
# 1    93.4          3.23          3.02          0.21       1.89
# 2    93.9          3.21          3.01          0.20       1.88
# 3    94.2          3.26          3.07          0.19       1.92
# 4    94.1          3.27          3.08          0.19       1.92
#
#    H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0             3.12       1307.75      1.03           1.75     152.3
# 1             3.03       1309.80      0.72           1.50     136.1
# 2             3.02       1310.24      0.19           0.63     171.6
# 3             3.08       1309.19      0.34           0.50     198.0
# 4             3.09       1309.00      0.32           0.63     214.3

# %%
#drop all columns apart from datetime and rename
df = clim[['Date Time','T (degC)']].rename(columns = {'T (degC)':'T','Date Time':'datetime'})
df.head()
# Out:
#               datetime     T
# 0  01.01.2009 00:10:00 -8.02
# 1  01.01.2009 00:20:00 -8.41
# 2  01.01.2009 00:30:00 -8.51
# 3  01.01.2009 00:40:00 -8.31
# 4  01.01.2009 00:50:00 -8.27

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10589 entries, 0 to 10588
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  10589 non-null  object
#  1   T         10589 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 165.6+ KB

# %%
df.plot(figsize = (15,5))
# Out:
# <Axes: >

# %%
df['datetime'] = pd.to_datetime(df['datetime'], format='%d.%m.%Y %H:%M:%S')

# %%
type(df['datetime'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.head(10)
# Out:
#              datetime     T
# 0 2009-01-01 00:10:00 -8.02
# 1 2009-01-01 00:20:00 -8.41
# 2 2009-01-01 00:30:00 -8.51
# 3 2009-01-01 00:40:00 -8.31
# 4 2009-01-01 00:50:00 -8.27
# 5 2009-01-01 01:00:00 -8.05
# 6 2009-01-01 01:10:00 -7.62
# 7 2009-01-01 01:20:00 -7.62
# 8 2009-01-01 01:30:00 -7.91
# 9 2009-01-01 01:40:00 -8.43

# %%
# Taking each 6th record as we need hourly data, so we can ignore every other record (which are on 10 min level)

# We can also take mean/median of each consecutive 6 records if that is a business requirement, but right now it is not.

df_hour_lvl = df[5::6].reset_index().drop('index', axis=1)

# %%
df_hour_lvl.shape
# Out:
# (1764, 2)

# %%
df_hour_lvl.head()
# Out:
#              datetime     T
# 0 2009-01-01 01:00:00 -8.05
# 1 2009-01-01 02:00:00 -8.88
# 2 2009-01-01 03:00:00 -8.81
# 3 2009-01-01 04:00:00 -9.05
# 4 2009-01-01 05:00:00 -9.63

# %%
plt.figure(figsize = (14,5))
sns.distplot(df_hour_lvl['T'])
# Out:
# /var/folders/qp/jnj6wwv54lv_p5tg2lly4ng00000gn/T/ipykernel_1805/223933328.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_hour_lvl['T'])
# <Axes: xlabel='T', ylabel='Density'>

# %%
df_hour_lvl['T'] = (df_hour_lvl['T'] - df_hour_lvl['T'].mean()) / df_hour_lvl['T'].std()

# %%
# we cannot simply provide a sequence of data points to an LSTM model for training and testing, 
# the input X sequence must be a 2D array [no of records, n_input], while the input y sequence must be a 1D array

#input LSTM 
def Sequential_Input_LSTM(df, input_sequence):
    df_np = df.to_numpy()
    X = []
    y = []
    
    for i in range(len(df_np) - input_sequence):
        row = [a for a in df_np[i:i + input_sequence]]
        X.append(row)
        label = df_np[i + input_sequence]
        y.append(label)
        
    return np.array(X), np.array(y)

# %%
n_input = 10      # number of historical inputs to be used for forecasting the future time series 

df_min_model_data = df_hour_lvl['T']

X, y = Sequential_Input_LSTM(df_min_model_data, n_input)

# %%
X.shape, y.shape
# Out:
# ((1754, 10), (1754,))

# %%
#Training data
X_train, y_train = X[:1400], y[:1400]

# Validation data
X_val, y_val = X[1400:1600], y[1400:1600]

# Test data
X_test, y_test = X[1600:], y[1600:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, LSTM, Dense
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam 

#Creating the LSTM Model
n_features = 1                        # number of input variables used for forecast (here, only 1 i.e. temperature)

model1 = Sequential()

model1.add(InputLayer((n_input,n_features)))
model1.add(LSTM(100, return_sequences = True))     
model1.add(LSTM(100, return_sequences = True))
model1.add(LSTM(50))
model1.add(Dense(8, activation = 'relu'))
model1.add(Dense(1, activation = 'linear'))

model1.summary()
# Out:
# 2025-10-14 19:43:37.647787: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 100)        │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 10, 100)        │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 50)             │        30,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │           408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151,817 (593.04 KB)
#  Trainable params: 151,817 (593.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(monitor = 'val_loss', patience = 2)

model1.compile(loss = MeanSquaredError(), optimizer = Adam(learning_rate = 0.0001), metrics = [RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 50, callbacks = [early_stop])
# Out:
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - loss: 0.8904 - root_mean_squared_error: 0.9436 - val_loss: 0.7190 - val_root_mean_squared_error: 0.8479
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6093 - root_mean_squared_error: 0.7806 - val_loss: 0.4408 - val_root_mean_squared_error: 0.6639
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3650 - root_mean_squared_error: 0.6042 - val_loss: 0.3609 - val_root_mean_squared_error: 0.6008
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.3325 - root_mean_squared_error: 0.5766 - val_loss: 0.3444 - val_root_mean_squared_error: 0.5869
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.3176 - root_mean_squared_error: 0.5636 - val_loss: 0.3412 - val_root_mean_squared_error: 0.5841
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.3048 - root_mean_squared_error: 0.5521 - val_loss: 0.3215 - val_root_mean_squared_error: 0.5670
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2919 - root_mean_squared_error: 0.5403 - val_loss: 0.3098 - val_root_mean_squared_error: 0.5566
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2746 - root_mean_squared_error: 0.5241 - val_loss: 0.2947 - val_root_mean_squared_error: 0.5429
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2605 - root_mean_squared_error: 0.5104 - val_loss: 0.2836 - val_root_mean_squared_error: 0.5326
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2393 - root_mean_squared_error: 0.4892 - val_loss: 0.2719 - val_root_mean_squared_error: 0.5215
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2197 - root_mean_squared_error: 0.4688 - val_loss: 0.2524 - val_root_mean_squared_error: 0.5024
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1931 - root_mean_squared_error: 0.4394 - val_loss: 0.2399 - val_root_mean_squared_error: 0.4898
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1745 - root_mean_squared_error: 0.4177 - val_loss: 0.2236 - val_root_mean_squared_error: 0.4729
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1651 - root_mean_squared_error: 0.4063 - val_loss: 0.2117 - val_root_mean_squared_error: 0.4602
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1588 - root_mean_squared_error: 0.3985 - val_loss: 0.2070 - val_root_mean_squared_error: 0.4550
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1486 - root_mean_squared_error: 0.3855 - val_loss: 0.1949 - val_root_mean_squared_error: 0.4415
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1417 - root_mean_squared_error: 0.3765 - val_loss: 0.1859 - val_root_mean_squared_error: 0.4311
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1395 - root_mean_squared_error: 0.3734 - val_loss: 0.1786 - val_root_mean_squared_error: 0.4227
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1305 - root_mean_squared_error: 0.3612 - val_loss: 0.1685 - val_root_mean_squared_error: 0.4105
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1234 - root_mean_squared_error: 0.3513 - val_loss: 0.1620 - val_root_mean_squared_error: 0.4025
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1164 - root_mean_squared_error: 0.3412 - val_loss: 0.1547 - val_root_mean_squared_error: 0.3933
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1120 - root_mean_squared_error: 0.3347 - val_loss: 0.1448 - val_root_mean_squared_error: 0.3805
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1055 - root_mean_squared_error: 0.3248 - val_loss: 0.1433 - val_root_mean_squared_error: 0.3786
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0985 - root_mean_squared_error: 0.3139 - val_loss: 0.1316 - val_root_mean_squared_error: 0.3628
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0925 - root_mean_squared_error: 0.3041 - val_loss: 0.1301 - val_root_mean_squared_error: 0.3607
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0845 - root_mean_squared_error: 0.2907 - val_loss: 0.1146 - val_root_mean_squared_error: 0.3385
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0772 - root_mean_squared_error: 0.2778 - val_loss: 0.1195 - val_root_mean_squared_error: 0.3456
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0686 - root_mean_squared_error: 0.2619 - val_loss: 0.1089 - val_root_mean_squared_error: 0.3300
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0602 - root_mean_squared_error: 0.2453 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3078
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0532 - root_mean_squared_error: 0.2306 - val_loss: 0.0852 - val_root_mean_squared_error: 0.2919
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0464 - root_mean_squared_error: 0.2154 - val_loss: 0.0824 - val_root_mean_squared_error: 0.2871
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0429 - root_mean_squared_error: 0.2072 - val_loss: 0.0717 - val_root_mean_squared_error: 0.2678
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0387 - root_mean_squared_error: 0.1966 - val_loss: 0.0615 - val_root_mean_squared_error: 0.2479
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0365 - root_mean_squared_error: 0.1912 - val_loss: 0.0617 - val_root_mean_squared_error: 0.2484
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0346 - root_mean_squared_error: 0.1859 - val_loss: 0.0667 - val_root_mean_squared_error: 0.2583

# %%
losses_df1 = pd.DataFrame(model1.history.history)
losses_df1
# Out:
#         loss  root_mean_squared_error  val_loss  val_root_mean_squared_error
# 0   0.890369                 0.943593  0.718989                     0.847932
# 1   0.609325                 0.780593  0.440796                     0.663924
# 2   0.365020                 0.604169  0.360934                     0.600778
# 3   0.332517                 0.576643  0.344409                     0.586864
# 4   0.317625                 0.563582  0.341182                     0.584108
# 5   0.304767                 0.552057  0.321500                     0.567010
# 6   0.291909                 0.540286  0.309797                     0.556594
# 7   0.274632                 0.524053  0.294745                     0.542904
# 8   0.260510                 0.510401  0.283633                     0.532572
# 9   0.239288                 0.489171  0.271948                     0.521487
# 10  0.219747                 0.468772  0.252409                     0.502403
# 11  0.193082                 0.439412  0.239864                     0.489760
# 12  0.174496                 0.417727  0.223639                     0.472904
# 13  0.165119                 0.406348  0.211750                     0.460163
# 14  0.158802                 0.398500  0.206993                     0.454965
# 15  0.148626                 0.385520  0.194934                     0.441513
# 16  0.141736                 0.376478  0.185887                     0.431146
# 17  0.139454                 0.373435  0.178643                     0.422661
# 18  0.130484                 0.361226  0.168535                     0.410530
# 19  0.123381                 0.351257  0.161976                     0.402462
# 20  0.116393                 0.341164  0.154656                     0.393263
# 21  0.112000                 0.334663  0.144751                     0.380462
# 22  0.105505                 0.324815  0.143303                     0.378554
# 23  0.098510                 0.313863  0.131625                     0.362802
# 24  0.092489                 0.304121  0.130123                     0.360726
# 25  0.084527                 0.290735  0.114575                     0.338489
# 26  0.077177                 0.277807  0.119469                     0.345642
# 27  0.068612                 0.261938  0.108920                     0.330031
# 28  0.060159                 0.245272  0.094741                     0.307800
# 29  0.053170                 0.230585  0.085207                     0.291902
# 30  0.046399                 0.215404  0.082432                     0.287110
# 31  0.042934                 0.207205  0.071719                     0.267803
# 32  0.038666                 0.196636  0.061456                     0.247904
# 33  0.036547                 0.191172  0.061687                     0.248368
# 34  0.034560                 0.185903  0.066733                     0.258327

# %%
losses_df1.plot(figsize = (10,6))
# Out:
# <Axes: >

# %%
scores = model1.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model1.metrics_names[0], scores[0]*100))
print("%s: %.2f%%" % ('RootMeanSquaredError', scores[1]*100))
# Out:
# loss: 6.79%
# RootMeanSquaredError: 26.06%

# %%
test_predictions1 = model1.predict(X_test).flatten()
test_predictions1
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step
# array([ 0.83154154,  0.7603987 ,  0.6558372 ,  0.5334401 ,  0.44192952,
#         0.38049787,  0.38903725,  0.5186144 ,  0.7001675 ,  0.8879011 ,
#         0.94909686,  0.9924732 ,  0.99963474,  1.0407844 ,  1.0450763 ,
#         1.0029408 ,  0.92160463,  0.8075191 ,  0.7286442 ,  0.6821985 ,
#         0.68890035,  0.6899165 ,  0.67929345,  0.65936655,  0.64161867,
#         0.6113246 ,  0.55548114,  0.5260091 ,  0.5235406 ,  0.5336407 ,
#         0.55525434,  0.6283621 ,  0.75025666,  0.88294667,  0.9657646 ,
#         0.97607005,  0.982656  ,  1.0001367 ,  1.0019243 ,  0.98100513,
#         0.9135896 ,  0.8148447 ,  0.7082837 ,  0.6272435 ,  0.5754021 ,
#         0.52856255,  0.47940323,  0.43197513,  0.37821853,  0.2748201 ,
#         0.21526355,  0.214796  ,  0.19115841,  0.14522043,  0.15822938,
#         0.36984265,  0.56840706,  0.79865307,  0.9316616 ,  1.0006673 ,
#         1.0466332 ,  1.0416999 ,  0.95506954,  0.9113449 ,  0.82782483,
#         0.7330497 ,  0.6698063 ,  0.6465301 ,  0.6720526 ,  0.6819999 ,
#         0.6726427 ,  0.65631557,  0.6509855 ,  0.58782357,  0.5344491 ,
#         0.47039258,  0.36946905,  0.2967401 ,  0.29059193,  0.32847726,
#         0.44375235,  0.65173316,  0.85482657,  0.89345133,  0.8027389 ,
#         0.67044544,  0.5787361 ,  0.5023715 ,  0.48582876,  0.52047527,
#         0.6014316 ,  0.7343809 ,  0.88975   ,  1.003052  ,  1.0814039 ,
#         1.0980291 ,  1.0731004 ,  1.02087   ,  0.94529617,  0.8863896 ,
#         0.83769166,  0.8243595 ,  0.87120014,  0.97340995,  1.1318116 ,
#         1.2948934 ,  1.4305663 ,  1.5310423 ,  1.6027039 ,  1.6300159 ,
#         1.6258439 ,  1.5836722 ,  1.4857696 ,  1.3492587 ,  1.2133446 ,
#         1.064852  ,  0.8767469 ,  0.6583489 ,  0.47536618,  0.2955476 ,
#         0.14967692,  0.05361504, -0.01174586, -0.04169794, -0.05018436,
#        -0.03906106,  0.04939256,  0.27776784,  0.6256645 ,  1.0454863 ,
#         1.3646947 ,  1.5416623 ,  1.6134217 ,  1.6418624 ,  1.6367909 ,
#         1.6170096 ,  1.5702786 ,  1.4866307 ,  1.3635871 ,  1.2482586 ,
#         1.161339  ,  1.115553  ,  1.1033121 ,  1.1473712 ,  1.196432  ,
#         1.2073829 ,  1.1689895 ,  1.0993258 ,  1.0451928 ,  0.9970362 ,
#         0.98545504,  1.0156516 ,  1.018165  ,  1.0320996 ], dtype=float32)

# %%
test_predictions1 = model1.predict(X_test).flatten()
test_predictions1
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# array([ 0.83154154,  0.7603987 ,  0.6558372 ,  0.5334401 ,  0.44192952,
#         0.38049787,  0.38903725,  0.5186144 ,  0.7001675 ,  0.8879011 ,
#         0.94909686,  0.9924732 ,  0.99963474,  1.0407844 ,  1.0450763 ,
#         1.0029408 ,  0.92160463,  0.8075191 ,  0.7286442 ,  0.6821985 ,
#         0.68890035,  0.6899165 ,  0.67929345,  0.65936655,  0.64161867,
#         0.6113246 ,  0.55548114,  0.5260091 ,  0.5235406 ,  0.5336407 ,
#         0.55525434,  0.6283621 ,  0.75025666,  0.88294667,  0.9657646 ,
#         0.97607005,  0.982656  ,  1.0001367 ,  1.0019243 ,  0.98100513,
#         0.9135896 ,  0.8148447 ,  0.7082837 ,  0.6272435 ,  0.5754021 ,
#         0.52856255,  0.47940323,  0.43197513,  0.37821853,  0.2748201 ,
#         0.21526355,  0.214796  ,  0.19115841,  0.14522043,  0.15822938,
#         0.36984265,  0.56840706,  0.79865307,  0.9316616 ,  1.0006673 ,
#         1.0466332 ,  1.0416999 ,  0.95506954,  0.9113449 ,  0.82782483,
#         0.7330497 ,  0.6698063 ,  0.6465301 ,  0.6720526 ,  0.6819999 ,
#         0.6726427 ,  0.65631557,  0.6509855 ,  0.58782357,  0.5344491 ,
#         0.47039258,  0.36946905,  0.2967401 ,  0.29059193,  0.32847726,
#         0.44375235,  0.65173316,  0.85482657,  0.89345133,  0.8027389 ,
#         0.67044544,  0.5787361 ,  0.5023715 ,  0.48582876,  0.52047527,
#         0.6014316 ,  0.7343809 ,  0.88975   ,  1.003052  ,  1.0814039 ,
#         1.0980291 ,  1.0731004 ,  1.02087   ,  0.94529617,  0.8863896 ,
#         0.83769166,  0.8243595 ,  0.87120014,  0.97340995,  1.1318116 ,
#         1.2948934 ,  1.4305663 ,  1.5310423 ,  1.6027039 ,  1.6300159 ,
#         1.6258439 ,  1.5836722 ,  1.4857696 ,  1.3492587 ,  1.2133446 ,
#         1.064852  ,  0.8767469 ,  0.6583489 ,  0.47536618,  0.2955476 ,
#         0.14967692,  0.05361504, -0.01174586, -0.04169794, -0.05018436,
#        -0.03906106,  0.04939256,  0.27776784,  0.6256645 ,  1.0454863 ,
#         1.3646947 ,  1.5416623 ,  1.6134217 ,  1.6418624 ,  1.6367909 ,
#         1.6170096 ,  1.5702786 ,  1.4866307 ,  1.3635871 ,  1.2482586 ,
#         1.161339  ,  1.115553  ,  1.1033121 ,  1.1473712 ,  1.196432  ,
#         1.2073829 ,  1.1689895 ,  1.0993258 ,  1.0451928 ,  0.9970362 ,
#         0.98545504,  1.0156516 ,  1.018165  ,  1.0320996 ], dtype=float32)

# %%
len(X_test), len(test_predictions1)
# Out:
# (154, 154)

# %%
# check the dimension of the output (should be 1 for time series forecast)

test_predictions1.ndim
# Out:
# 1

# %%
X_test_list = []
for i in range(len(X_test)):
    X_test_list.append(X_test[i][0])
    
len(X_test_list)
# Out:
# 154

# %%
test_predictions_df1 = pd.DataFrame({'X_test':list(X_test_list), 'LSTM Prediction':list(test_predictions1)})
len(test_predictions_df1)
# Out:
# 154

# %%
test_predictions_df1.head()
# Out:
#      X_test  LSTM Prediction
# 0  1.166509         0.831542
# 1  1.118522         0.760399
# 2  1.143475         0.655837
# 3  1.168429         0.533440
# 4  1.107005         0.441930

# %%
test_predictions_df1.plot(figsize = (15,6))
# Out:
# <Axes: >
